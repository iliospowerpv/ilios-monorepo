# %%
import os
from pathlib import Path
from typing import List

import numpy as np
import pandas as pd
from langchain.chains import LLMChain
from tqdm import tqdm
from datetime import datetime

from src.gen_ai.gen_ai import get_llm
from src.pipelines.term_extraction.utils import get_project_preview

os.environ["DOC_AI_LOCATION"] = "us"
os.environ["PROJECT_ID"] = "602280418311"
os.environ["LOCATION"] = "us-west1"
os.environ["AWS_ACCESS_KEY_ID"] = "AKIA3FLDZKXBZON2YNPB"
os.environ["AWS_SECRET_ACCESS_KEY"] = "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"
os.environ["GOOGLE_API_KEY"]="AIzaSyBs6eyE7JHovx_7Jp0RmO-SasqLaJk5rlI"
os.environ["PROJECT_ID"]="602280418311"
os.environ["DOC_AI_LOCATION"]="us"
os.environ["DOC_AI_PROCESSOR_ID"]="e977fdd46ee23308"

# %%
str(AgreementType.OPERATING_AGREEMENT.value)

# %%
from src.pipelines.constants import AgreementType
from src.pipelines.file_enrichment.pipeline import FileEnrichmentPipeline

pipeline = FileEnrichmentPipeline()

ans = pipeline.run(
    {
        "file_link": "gs://doc_ai_storage/operating-agreement/documents/Cape Fear - Hills Energy Holding_ LLC - Amended and Restated Operating Agreement [Executed].pdf",
        "file_id": 1,
        "site_name": "site_name_test",
        "site_id": 1,
        "company_name": "company_name_test",
        "company_id": 1,
        "agreement_name": str(AgreementType.OPERATING_AGREEMENT.value),
        }
)

# %%
for i in ans:
    print(i["risks"])

# %%
"""
The document contains several defined terms related to tax credits (ITC, Recapture Amount, Recapture Event) which could pose risks if the tax credits are reduced, recaptured or disallowed for any reason. There are also references to options for the purchase or sale of membership interests (Purchase Option, Sale Option) which could involve risks if exercised improperly or at an unfavorable price. The document is an operating agreement which governs the operations and management of the company, so any ambiguities or unfavorable terms in the agreement could pose operational and management risks.

The provided document appears to be an operating agreement for a limited liability company (LLC) called Hills Energy Holding, LLC. While the document itself does not contain explicit risks or issues, operating agreements generally outline the rights, responsibilities, and obligations of the members, as well as the management and governance structure of the LLC. Without reviewing the entire agreement, it is difficult to identify specific risks or issues. However, some potential risks or issues that could arise in an operating agreement include unclear or ambiguous language, unbalanced allocation of rights and responsibilities among members, inadequate provisions for resolving disputes or managing conflicts of interest, lack of provisions for transferring membership interests or admitting new members, and failure to comply with applicable state laws governing LLCs. It is recommended to have an experienced attorney review the entire operating agreement to identify and mitigate any potential risks or issues."""
