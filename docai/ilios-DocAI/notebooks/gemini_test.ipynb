# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro",
                             temperature=0.7, top_p=0.85, google_api_key="AIzaSyBs6eyE7JHovx_7Jp0RmO-SasqLaJk5rlI")

# %%
llm.invoke("Are you gemini?")
