# %%
import pandas as pd

# %%
rules = pd.read_csv('poison-pills-rules.csv')

# %%
rules
# Out:
#                            Name  \
# 0      Lessor must be landowner
# 1      Unilaterally termination
# 2             Fair Market Value
# 3         Clause with confusion
# 4   Too long construction terms
# 5     Unclear calculation logic
# 6           Prepayment required
# 7      Production factor issues
# 8               Uncovered scope
# 9             Guaranties Issues
# 10                      PG NOTE
#
#                                          Prompt Short  \
# 0      Lessor must be landowner or have right to rent
# 1   One Party can unilaterally terminate the contr...
# 2                  Buyout should be fair market value
# 3         Issue in the clause that leads to confusion
# 4   Terms of the construction can take to long fro...
# 5   Not clear logic of calculation from agreements...
# 6              Some of the things require pre-payment
# 7   Production factor Must be P50. If P90 - it is ...
# 8   Scope & Services must include mowing/vegetatio...
# 9                 Not covering what Investors require
# 10  If No Personal Guarantee (PG) Promissory Note ...
#
#                                                Prompt  \
# 0   Lessor must be landowner or have right to rent...
# 1   One Party must not be able to unilaterally ter...
# 2                 Buyout should be fair market value.
# 3        Issue in the clause that leads to confusion.
# 4   Terms of the construction can take to long fro...
# 5   Not clear logic of calculation from agreements...
# 6        No pre-payment in any form must be required.
# 7   Production factor Must be P50. If P90 - it is ...
# 8   Scope & Services must include mowing/vegetatio...
# 9                Not covering what Investors require.
# 10  If No Personal Guarantee (PG) Promissory Note ...
#
#                                             Key Items   Agreement Type
# 0                              Fee Simple Owner (Y/N)              All
# 1   Termination & Removal - Lessee;Termination & R...              All
# 2   Termination & Removal - Lessee;Termination & R...              All
# 3                                                 All              All
# 4                         Mechanical Completion Date;              PPA
# 5   Rent Amount;Term;Power Purchase Agreement Rate...  Site Lease;PPA;
# 6                       Rent Amount;Rent Calculation;  Site Lease;PPA;
# 7                                   Production Factor              OM;
# 8                                    Scope & Services              OM;
# 9                                          Guaranties          EPC;OM;
# 10                                         Guaranties          EPC;OM;

# %%
rules.loc[0, 'Prompt'] = 'Lessor must be landowner or have right to rent. No relevant text is alarming. Short term value equal to N, means that the Lessor is not a fee simple owner, which also is a violation of the rule.'

# %%
rules.to_csv('poison-pills-rules.csv', index=False)

# %%
pp = pd.read_csv('output_ppills.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pp = pd.read_csv('output_ppills.csv')
#
# File ~/miniconda3/envs/ilios-docai/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/ilios-docai/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/ilios-docai/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/ilios-docai/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/ilios-docai/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_ppills.csv'

# %%
pp
# Out:
#     Unnamed: 0                          Key Items  \
# 0            0      Lessor (Landlord) Entity Name
# 1            1        Lessee (Tenant) Entity Name
# 2            2                     Effective Date
# 3            3                      Property Size
# 4            4                       Initial Term
# 5            5                  Rent Commencement
# 6            6                      Renewal Terms
# 7            7                   Rent Calculation
# 8            8                        Rent Amount
# 9            9                      Payment Terms
# 10          10                  First Payment Due
# 11          11                    Expiration Date
# 12          12                Renewal Notice Term
# 13          13        Site Lease Prepayment (Y/N)
# 14          14     Site Lease Prepayment (Amount)
# 15          15    Removal Timeline & Expectations
# 16          16             Fee Simple Owner (Y/N)
# 17          17               Rent Escalator (Y/N)
# 18          18          Rent Escalator (Schedule)
# 19          19      Rent Escalator Effective Date
# 20          20     Termination & Removal - Lessee
# 21          21     Termination & Removal - Lessor
# 22          22  Termination - Notice Requirements
# 23          23                            Default
# 24          24               Assignment by Lessee
# 25          25               Assignment by Lessor
# 26          26               Removal Requirements
# 27          27                 Site Access Rights
# 28          28                    Quiet Enjoyment
# 29          29       Non-Disturbance Requirements
# 30          30                               SNDA
# 31          31                     Eminent Domain
# 32          32                      Force Majeure
# 33          33                   Property Tax ($)
# 34          34             Purchase Options (Y/N)
# 35          35                              Liens
# 36          36        Amendments and/or Estoppels
# 37          37   Prevailing Party Provision (Y/N)
# 38          38                      Governing Law
#
#                                                 Value  \
# 0                    California Property Owner I, LLC
# 1                       Blue Sky Utility Holding, LLC
# 2                                     January 1, 2022
# 3                                                 NaN
# 4   Begins on the Effective Date and extends 25 ye...
# 5                           Commercial Operation Date
# 6                  Twenty-five (25) year initial term
# 7   $11,500 per year with 2% annual escalation, pa...
# 8   $5,000 for the first four (4) months, then $3,...
# 9   Initial Pre-Construction Rent: $5,000 for the ...
# 10                   On the Commercial Operation Date
# 11                   25 years from the Effective Date
# 12                                                NaN
# 13                                                No.
# 14                                                NaN
# 15                     60 days notice\n30 days notice
# 16                                                  Y
# 17                                                  Y
# 18                         Key item is not supported.
# 19         1 year after the Commercial Operation Date
# 20                See Sections I.D.2a, I.D.2c, I.D.2d
# 21                                       90d\n5y\n60d
# 22  Default Termination Notice: Written notice in ...
# 23                             VI.A, VI.B, VI.C, VI.D
# 24                                                Yes
# 25  Landlord can assign to an Affiliate or Subsequ...
# 26  Tenant shall remove the Solar System and resto...
# 27  Tenant has access to the premises for installa...
# 28  Subject to no material interference with other...
# 29                                 See Section "SNDA"
# 30                         Key item is not supported.
# 31  Lease terminates when condemning authority tak...
# 32                                    See Section G.1
# 33                                      See Section 1
# 34                                                  Y
# 35                                         Prohibited
# 36         Estoppels due within 30 days from request.
# 37                                                  Y
# 38                                State of California
#
#                                           Legal Terms  \
# 0   The relevant text from the document is:\n\n"TH...
# 1   The term "Lessee (Tenant) Entity Name" is not ...
# 2   The relevant section containing the term "Effe...
# 3                                                 NaN
# 4   The relevant sections containing information a...
# 5   The relevant sections containing the term "Ren...
# 6   The relevant section containing information ab...
# 7   The relevant sections containing information a...
# 8   Here are the relevant excerpts from the docume...
# 9   The relevant sections containing information a...
# 10  The relevant section containing information ab...
# 11  The relevant section containing the term "Expi...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  The relevant sections containing information a...
# 16  Based on the document, here are the relevant s...
# 17  Based on the document, the relevant section co...
# 18                         Key item is not supported.
# 19  The relevant section containing the term "Rent...
# 20  Here are the relevant excerpts from the docume...
# 21  The relevant sections from the document contai...
# 22  The relevant sections containing information a...
# 23  The relevant sections containing the term "Def...
# 24  The relevant section containing the term "Assi...
# 25  The relevant sections from the document regard...
# 26  The relevant sections containing information a...
# 27  The relevant sections containing information a...
# 28  The relevant sections containing the term "qui...
# 29  The relevant section containing information ab...
# 30                         Key item is not supported.
# 31  The relevant section containing the term "Emin...
# 32  The relevant section containing the term "Forc...
# 33  The relevant text from the document is:\n\n"1....
# 34  The document contains the following relevant t...
# 35  The relevant section containing the term "Lien...
# 36  The relevant section containing information ab...
# 37  The relevant section containing the term "Prev...
# 38  The relevant section containing the term "Gove...
#
#                                          Poison Pills Poison Pills Presented  \
# 0   Yes, the "Clause with confusion" rule is viola...                    yes
# 1   No poison pill rules violations are present be...                     no
# 2   No poison pill rules violations are present be...                     no
# 3   No poison pill rules violations are present be...                     no
# 4   No poison pill rules violations are present be...                     no
# 5   No poison pill rules violations are present be...                     no
# 6   Yes, a "Clause with confusion" rule violation ...                    yes
# 7   Yes, the "Clause with confusion" rule is viola...                    yes
# 8   Yes, the "Unclear calculation logic" rule is v...                    yes
# 9   No poison pill rules violations are present be...                     no
# 10  No poison pill rules violations are present be...                     no
# 11  No poison pill rules violations are present be...                     no
# 12  No poison pill rules violations are present be...                     no
# 13  No poison pill rules violations are present be...                     no
# 14  No poison pill rules violations are present be...                     no
# 15  No poison pill rules violations are present be...                     no
# 16  No poison pill rules violations are present be...                     no
# 17  No poison pill rules violations are present be...                     no
# 18                                                NaN                    NaN
# 19  No poison pill rules violations are present be...                     no
# 20  No poison pill rules violations are present be...                     no
# 21  No poison pill rules violations are present be...                     no
# 22  Yes, the lease violates the rule against unila...                    yes
# 23  No poison pill rules violations are present be...                     no
# 24  No poison pill rules violations are present be...                     no
# 25  No poison pill rules violations are present be...                     no
# 26  No poison pill rules violations are present be...                     no
# 27  No poison pill rules violations are present be...                     no
# 28  Yes, the rule "Clause with confusion" is viola...                    yes
# 29  Yes, the SNDA clause violates the "Clause with...                    yes
# 30                                                NaN                    NaN
# 31  No poison pill rules violations are present be...                     no
# 32  Yes, the force majeure clause presents potenti...                    yes
# 33  No poison pill rules violations are present be...                     no
# 34  Yes, the rule "Issue in the clause that leads ...                    yes
# 35  No poison pill rules violations are present be...                     no
# 36  No poison pill rules violations are present be...                     no
# 37  Yes, the "Prevailing Party" clause violates th...                    yes
# 38  No poison pill rules violations are present be...                     no
#
#                                 Poison Pills Detailed
# 0   * **Misleading Entity Name Creates Confusion:*...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   * **Misrepresentation of Lease Term:** The tex...
# 7   * **Unclear Relationship Between Base and Perc...
# 8   **Regarding "Unclear calculation logic":**\n\n...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  * **Unilateral Termination for Tenant Default ...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  * **Inconsistent Standards for Material Interf...
# 29  * **Vague Interference Clause:** The SNDA's pr...
# 30                                                NaN
# 31                                                NaN
# 32  * **Overly Broad Definition of Force Majeure:*...
# 33                                                NaN
# 34  * **Vague Participation Rights:** The text's a...
# 35                                                NaN
# 36                                                NaN
# 37  * **Lacks Definition of "Prevailing Party":** ...
# 38                                                NaN

# %%
pp.loc[16, 'Value'] = 'N'

# %%
pp.to_csv('output_ppills.csv', index=False)

# %%
pp_final = pd.read_csv('output_ppills_final.csv')

# %%
pp_final
# Out:
#     Unnamed: 0.1  Unnamed: 0                          Key Items  \
# 0              0           0      Lessor (Landlord) Entity Name
# 1              1           1        Lessee (Tenant) Entity Name
# 2              2           2                     Effective Date
# 3              3           3                      Property Size
# 4              4           4                       Initial Term
# 5              5           5                  Rent Commencement
# 6              6           6                      Renewal Terms
# 7              7           7                   Rent Calculation
# 8              8           8                        Rent Amount
# 9              9           9                      Payment Terms
# 10            10          10                  First Payment Due
# 11            11          11                    Expiration Date
# 12            12          12                Renewal Notice Term
# 13            13          13        Site Lease Prepayment (Y/N)
# 14            14          14     Site Lease Prepayment (Amount)
# 15            15          15    Removal Timeline & Expectations
# 16            16          16             Fee Simple Owner (Y/N)
# 17            17          17               Rent Escalator (Y/N)
# 18            18          18          Rent Escalator (Schedule)
# 19            19          19      Rent Escalator Effective Date
# 20            20          20     Termination & Removal - Lessee
# 21            21          21     Termination & Removal - Lessor
# 22            22          22  Termination - Notice Requirements
# 23            23          23                            Default
# 24            24          24               Assignment by Lessee
# 25            25          25               Assignment by Lessor
# 26            26          26               Removal Requirements
# 27            27          27                 Site Access Rights
# 28            28          28                    Quiet Enjoyment
# 29            29          29       Non-Disturbance Requirements
# 30            30          30                               SNDA
# 31            31          31                     Eminent Domain
# 32            32          32                      Force Majeure
# 33            33          33                   Property Tax ($)
# 34            34          34             Purchase Options (Y/N)
# 35            35          35                              Liens
# 36            36          36        Amendments and/or Estoppels
# 37            37          37   Prevailing Party Provision (Y/N)
# 38            38          38                      Governing Law
#
#                                                 Value  \
# 0                    California Property Owner I, LLC
# 1                       Blue Sky Utility Holding, LLC
# 2                                     January 1, 2022
# 3                                                 NaN
# 4   Begins on the Effective Date and extends 25 ye...
# 5                           Commercial Operation Date
# 6                  Twenty-five (25) year initial term
# 7   $11,500 per year with 2% annual escalation, pa...
# 8   $5,000 for the first four (4) months, then $3,...
# 9   Initial Pre-Construction Rent: $5,000 for the ...
# 10                   On the Commercial Operation Date
# 11                   25 years from the Effective Date
# 12                                                NaN
# 13                                                No.
# 14                                                NaN
# 15                     60 days notice\n30 days notice
# 16                                                  N
# 17                                                  Y
# 18                         Key item is not supported.
# 19         1 year after the Commercial Operation Date
# 20                See Sections I.D.2a, I.D.2c, I.D.2d
# 21                                       90d\n5y\n60d
# 22  Default Termination Notice: Written notice in ...
# 23                             VI.A, VI.B, VI.C, VI.D
# 24                                                Yes
# 25  Landlord can assign to an Affiliate or Subsequ...
# 26  Tenant shall remove the Solar System and resto...
# 27  Tenant has access to the premises for installa...
# 28  Subject to no material interference with other...
# 29                                 See Section "SNDA"
# 30                         Key item is not supported.
# 31  Lease terminates when condemning authority tak...
# 32                                    See Section G.1
# 33                                      See Section 1
# 34                                                  Y
# 35                                         Prohibited
# 36         Estoppels due within 30 days from request.
# 37                                                  Y
# 38                                State of California
#
#                                           Legal Terms  \
# 0   The relevant text from the document is:\n\n"TH...
# 1   The term "Lessee (Tenant) Entity Name" is not ...
# 2   The relevant section containing the term "Effe...
# 3                                                 NaN
# 4   The relevant sections containing information a...
# 5   The relevant sections containing the term "Ren...
# 6   The relevant section containing information ab...
# 7   The relevant sections containing information a...
# 8   Here are the relevant excerpts from the docume...
# 9   The relevant sections containing information a...
# 10  The relevant section containing information ab...
# 11  The relevant section containing the term "Expi...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  The relevant sections containing information a...
# 16  Based on the document, here are the relevant s...
# 17  Based on the document, the relevant section co...
# 18                         Key item is not supported.
# 19  The relevant section containing the term "Rent...
# 20  Here are the relevant excerpts from the docume...
# 21  The relevant sections from the document contai...
# 22  The relevant sections containing information a...
# 23  The relevant sections containing the term "Def...
# 24  The relevant section containing the term "Assi...
# 25  The relevant sections from the document regard...
# 26  The relevant sections containing information a...
# 27  The relevant sections containing information a...
# 28  The relevant sections containing the term "qui...
# 29  The relevant section containing information ab...
# 30                         Key item is not supported.
# 31  The relevant section containing the term "Emin...
# 32  The relevant section containing the term "Forc...
# 33  The relevant text from the document is:\n\n"1....
# 34  The document contains the following relevant t...
# 35  The relevant section containing the term "Lien...
# 36  The relevant section containing information ab...
# 37  The relevant section containing the term "Prev...
# 38  The relevant section containing the term "Gove...
#
#                                        Poison Pills_x  \
# 0   Yes, the "Clause with confusion" rule is viola...
# 1   No poison pill rules violations are present be...
# 2   No poison pill rules violations are present be...
# 3   No poison pill rules violations are present be...
# 4   No poison pill rules violations are present be...
# 5   No poison pill rules violations are present be...
# 6   Yes, a "Clause with confusion" rule violation ...
# 7   Yes, the "Clause with confusion" rule is viola...
# 8   Yes, the "Unclear calculation logic" rule is v...
# 9   No poison pill rules violations are present be...
# 10  No poison pill rules violations are present be...
# 11  No poison pill rules violations are present be...
# 12  No poison pill rules violations are present be...
# 13  No poison pill rules violations are present be...
# 14  No poison pill rules violations are present be...
# 15  No poison pill rules violations are present be...
# 16  No poison pill rules violations are present be...
# 17  No poison pill rules violations are present be...
# 18                                                NaN
# 19  No poison pill rules violations are present be...
# 20  No poison pill rules violations are present be...
# 21  No poison pill rules violations are present be...
# 22  Yes, the lease violates the rule against unila...
# 23  No poison pill rules violations are present be...
# 24  No poison pill rules violations are present be...
# 25  No poison pill rules violations are present be...
# 26  No poison pill rules violations are present be...
# 27  No poison pill rules violations are present be...
# 28  Yes, the rule "Clause with confusion" is viola...
# 29  Yes, the SNDA clause violates the "Clause with...
# 30                                                NaN
# 31  No poison pill rules violations are present be...
# 32  Yes, the force majeure clause presents potenti...
# 33  No poison pill rules violations are present be...
# 34  Yes, the rule "Issue in the clause that leads ...
# 35  No poison pill rules violations are present be...
# 36  No poison pill rules violations are present be...
# 37  Yes, the "Prevailing Party" clause violates th...
# 38  No poison pill rules violations are present be...
#
#    Poison Pills Presented_x  \
# 0                       yes
# 1                        no
# 2                        no
# 3                        no
# 4                        no
# 5                        no
# 6                       yes
# 7                       yes
# 8                       yes
# 9                        no
# 10                       no
# 11                       no
# 12                       no
# 13                       no
# 14                       no
# 15                       no
# 16                       no
# 17                       no
# 18                      NaN
# 19                       no
# 20                       no
# 21                       no
# 22                      yes
# 23                       no
# 24                       no
# 25                       no
# 26                       no
# 27                       no
# 28                      yes
# 29                      yes
# 30                      NaN
# 31                       no
# 32                      yes
# 33                       no
# 34                      yes
# 35                       no
# 36                       no
# 37                      yes
# 38                       no
#
#                                 Poison Pills Detailed  \
# 0   * **Misleading Entity Name Creates Confusion:*...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   * **Misrepresentation of Lease Term:** The tex...
# 7   * **Unclear Relationship Between Base and Perc...
# 8   **Regarding "Unclear calculation logic":**\n\n...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  * **Unilateral Termination for Tenant Default ...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  * **Inconsistent Standards for Material Interf...
# 29  * **Vague Interference Clause:** The SNDA's pr...
# 30                                                NaN
# 31                                                NaN
# 32  * **Overly Broad Definition of Force Majeure:*...
# 33                                                NaN
# 34  * **Vague Participation Rights:** The text's a...
# 35                                                NaN
# 36                                                NaN
# 37  * **Lacks Definition of "Prevailing Party":** ...
# 38                                                NaN
#
#                                        Poison Pills_y  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   * **Creates Contractual Ambiguity:** The text ...
# 7                                                 NaN
# 8   **Unclear Calculation Logic Violations:**\n\n*...
# 9   * **Undefined "Commencement of Construction":*...
# 10                                                NaN
# 11  * **Inconsistent Terminology:** The text uses ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  * **Conflicting Removal Timelines:** The claus...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  * **Unilateral Termination Right (I.D.2c):** T...
# 21  * **I.D.2.a:** Grants the Landlord unilateral ...
# 22  * **Unilateral Termination for Default (I.D.2....
# 23  * **Lack of Specificity and Ambiguity:** Secti...
# 24  * **Subjective Approval Criteria:** The phrase...
# 25                                                NaN
# 26                                                NaN
# 27  * **Lack of Objective Criteria:** The phrase "...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  * **Ambiguous Participation Right:** The text ...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                         Full Comments  \
# 0   Rule name: Clause with confusion:\nComment:The...
# 1   Rule name: Clause with confusion:\nComment:The...
# 2   Rule name: Clause with confusion:\nComment:The...
# 3                                                 NaN
# 4   Rule name: Clause with confusion:\nComment:The...
# 5   Rule name: Clause with confusion:\nComment:The...
# 6   Rule name: Clause with confusion:\nComment:The...
# 7   Rule name: Clause with confusion:\nComment:The...
# 8   Rule name: Clause with confusion:\nComment:The...
# 9   Rule name: Clause with confusion:\nComment:The...
# 10  Rule name: Clause with confusion:\nComment:The...
# 11  Rule name: Clause with confusion:\nComment:The...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Rule name: Clause with confusion:\nComment:The...
# 16  Rule name: Lessor must be landowner:\nComment:...
# 17  Rule name: Clause with confusion:\nComment:The...
# 18                                                NaN
# 19  Rule name: Clause with confusion:\nComment:The...
# 20  Rule name: Unilaterally termination:\nComment:...
# 21  Rule name: Unilaterally termination:\nComment:...
# 22  Rule name: Unilaterally termination:\nComment:...
# 23  Rule name: Clause with confusion:\nComment:The...
# 24  Rule name: Clause with confusion:\nComment:The...
# 25  Rule name: Clause with confusion:\nComment:The...
# 26  Rule name: Clause with confusion:\nComment:The...
# 27  Rule name: Clause with confusion:\nComment:The...
# 28  Rule name: Clause with confusion:\nComment:The...
# 29  Rule name: Clause with confusion:\nComment:The...
# 30                                                NaN
# 31  Rule name: Clause with confusion:\nComment:The...
# 32  Rule name: Clause with confusion:\nComment:The...
# 33  Rule name: Clause with confusion:\nComment:The...
# 34  Rule name: Clause with confusion:\nComment:The...
# 35  Rule name: Clause with confusion:\nComment:The...
# 36  Rule name: Clause with confusion:\nComment:The...
# 37  Rule name: Clause with confusion:\nComment:The...
# 38  Rule name: Clause with confusion:\nComment:The...
#
#    Poison Pills Presented_y                                       Poison Pills
# 0                        no  No poison pill rules violations are present be...
# 1                        no  No poison pill rules violations are present be...
# 2                        no  No poison pill rules violations are present be...
# 3                       NaN                                                NaN
# 4                        no  No poison pill rules violations are present be...
# 5                        no  No poison pill rules violations are present be...
# 6                       yes  Yes, the "Clause with confusion" rule is viola...
# 7                        no  No poison pill rules violations are present be...
# 8                       yes  Yes, the "Unclear calculation logic" rule is v...
# 9                       yes  Yes, the rule "Issue in the clause that leads ...
# 10                       no  No poison pill rules violations are present be...
# 11                      yes  Yes, the rule "Issue in the clause that leads ...
# 12                      NaN                                                NaN
# 13                      NaN                                                NaN
# 14                      NaN                                                NaN
# 15                      yes  Yes, the "Clause with confusion" rule is viola...
# 16                       no  No poison pill rules violations are present be...
# 17                       no  No poison pill rules violations are present be...
# 18                      NaN                                                NaN
# 19                       no  No poison pill rules violations are present be...
# 20                      yes  A: Yes, sections I.D.2c and I.D.2d violate the...
# 21                      yes  Yes, the lease contains poison pill violations...
# 22                      yes  Yes, the lease violates the rule against unila...
# 23                      yes  Potential rule violations exist in sections VI...
# 24                      yes  Yes, the "Clause with confusion" rule is viola...
# 25                       no  No poison pill rules violations are present be...
# 26                       no  No poison pill rules violations are present be...
# 27                      yes  Yes, the lease contains potentially problemati...
# 28                       no  No poison pill rules violations are present be...
# 29                       no  No poison pill rules violations are present be...
# 30                      NaN                                                NaN
# 31                       no  No poison pill rules violations are present be...
# 32                       no  No poison pill rules violations are present be...
# 33                       no  No poison pill rules violations are present be...
# 34                      yes  Yes, the "Clause with confusion" rule is viola...
# 35                       no  No poison pill rules violations are present be...
# 36                       no  No poison pill rules violations are present be...
# 37                       no  No poison pill rules violations are present be...
# 38                       no  No poison pill rules violations are present be...

# %%
import textwrap

prompt = textwrap.dedent(
    """
    YOU ARE A SENIOR DUE DILIGENCE MANAGER AT A LEADING SOLAR ENERGY COMPANY, TASKED WITH THE CRITICAL RESPONSIBILITY OF VERIFYING THE ACCURACY AND COMPLIANCE OF TEXT CITATIONS WITHIN DOCUMENTS RELATED TO SOLAR ENERGY PROJECTS. YOUR EXPERTISE IN LEGAL AND REGULATORY COMPLIANCE IS ESSENTIAL TO ENSURE THAT ALL CONTRACTS AND AGREEMENTS REFLECT THE CORRECT LEGAL STANDARDS AND COMPANY POLICIES.
    
    **Task Description:**
    - REVIEW the provided text containing citations from a document.
    - CHECK each citation against the specified rule: "{rule}."
    - PROVIDE expert feedback: If a citation violates the rule, detail the specific issue and suggest corrective actions. If all citations comply, return the phrase "{no_poison_pills_str}."
    
    **Chain of Thoughts:**
    1. **Understanding the Rule:**
       - Clearly comprehend the rule regarding leasing and property rights to apply it accurately during the review.
       - Note the key components of the rule which focus on ownership and leasing rights.
    
    2. **Reviewing the Text:**
       - Identify each citation in the text that pertains to leasing or property rights.
       - Analyze the context and content of these citations to see if they conform to the rule.
    
    3. **Evaluation and Feedback:**
       - For each citation that violates the rule, explain the discrepancy and provide detailed advice on how to address the issue.
       - If all citations are compliant, confirm this with the specified safe phrase.
    
    4. **Documentation and Reporting:**
       - Document your findings and recommendations clearly and concisely.
       - Prepare a summary report of the compliance check for internal use.
    
    **What Not To Do:**
    - DO NOT OVERLOOK ANY CITATION THAT REQUIRES REVIEW.
    - AVOID MISINTERPRETING THE RULE OR APPLYING IT INCORRECTLY.
    - NEVER LEAVE ERRORS UNADDRESSED IN THE FEEDBACK.
    - DO NOT FORGET TO PROVIDE CLEAR AND ACTIONABLE RECOMMENDATIONS FOR NON-COMPLIANT ISSUES.
    - DO NOT FAIL TO USE THE SPECIFIED PHRASE "{no_poison_pills_str}" WHEN ALL CITATIONS ARE COMPLIANT.
    
    Rule that needs to be checked for alignment with the legal terms:
    ```
    {rule}
    ```
    Short version of the term that needs to be checked for alignment with the rule:
    ```
    {short_term}
    ```
    Legal terms that need to be checked for alignment with the rule:
    ```
    {legal_term}
    ```
    ANSWER:"""
)

# %%
from langchain_core.prompts import PromptTemplate
from src.pipelines.constants import NO_POISON_PILLS_STR

legal_term = """The relevant section is: 16i. Owner is the fee owner of the Premises and the Easements and the lands immediately adjacent"""

short_term = """N"""

rule = """Lessor must be landowner or have right to rent. No relevant text is alarming. Short term value equal to N, means that the Lessor is not a fee simple owner, which also is a violation of the rule."""

prompt = PromptTemplate.from_template(prompt).format(
    no_poison_pills_str=NO_POISON_PILLS_STR,
    legal_term=legal_term,
    short_term=short_term,
    rule=rule,
)

# %%
from src.gen_ai.gen_ai import get_llm
import os 

os.environ['AWS_ACCESS_KEY_ID']="AKIA3FLDZKXBZON2YNPB"
os.environ['AWS_SECRET_ACCESS_KEY']="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"
llm = get_llm(model_type="CLAUDE")
# Out:
# /Users/mkaczo/Desktop/Projects/iliOS/ilios-DocAI/src/gen_ai/gen_ai.py:89: LangChainBetaWarning: Introduced in 0.2.24. API subject to change.
#   return InMemoryRateLimiter(

# %%
result = llm.batch([prompt])

# %%
result
# Out:
# [AIMessage(content='The citation "16i. Owner is the fee owner of the Premises and the Easements and the lands immediately adjacent" appears to comply with the rule that "Lessor must be landowner or have right to rent." This statement explicitly mentions that the Owner is the fee owner of the premises and easements, indicating that they have ownership rights over the property being leased.\n\nHowever, the rule also states that "Short term value equal to N, means that the Lessor is not a fee simple owner, which also is a violation of the rule." If the term "N" is used in the context of the lease agreement to indicate a short-term value or duration, it would suggest that the Lessor does not have full fee simple ownership rights, which would violate the rule.\n\nTo ensure full compliance, I recommend reviewing the lease agreement thoroughly to verify that the term "N" is not used in a manner that contradicts the Lessor\'s fee simple ownership status. If the term "N" is used in such a way, it should be addressed and clarified to align with the rule.\n\nIf no instances of the term "N" are found or if it is used in a context that does not conflict with the Lessor\'s fee simple ownership, then the citation provided can be considered compliant with the rule.', additional_kwargs={'usage': {'prompt_tokens': 698, 'completion_tokens': 280, 'total_tokens': 978}, 'stop_reason': 'stop_sequence', 'model_id': 'anthropic.claude-3-sonnet-20240229-v1:0'}, response_metadata={'usage': {'prompt_tokens': 698, 'completion_tokens': 280, 'total_tokens': 978}, 'stop_reason': 'stop_sequence', 'model_id': 'anthropic.claude-3-sonnet-20240229-v1:0'}, id='run-3e680c17-4d65-4375-8be7-b478e39df9c1-0', usage_metadata={'input_tokens': 698, 'output_tokens': 280, 'total_tokens': 978})]
