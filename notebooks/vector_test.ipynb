# %%
import os

from src.vectordb.pg_vector.retriever import PGVectorRetriever
from src.vectordb.pg_vector.connector import PGVectorConnector
from src.vectordb.pg_vector.config import PGVectorConfig

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'prj-ilios-ai.json'
os.environ['PROJECT_ID'] = '602280418311'

# %%
retriever = PGVectorRetriever(db_connector=PGVectorConnector(config=PGVectorConfig()))

# %%
result = retriever.get_risks({"site_id": 101, "agreement_type": "NDA"})

# %%
result
