# %%
import os
from pathlib import Path
from typing import List

import numpy as np
import pandas as pd
from langchain.chains import LLMChain
from tqdm import tqdm
from datetime import datetime

from src.gen_ai.gen_ai import get_llm
from src.pipelines.term_extraction.utils import get_project_preview

os.environ["DOC_AI_LOCATION"] = "us"
os.environ["PROJECT_ID"] = "602280418311"
os.environ["LOCATION"] = "us-west1"
os.environ["AWS_ACCESS_KEY_ID"] = "AKIA3FLDZKXBZON2YNPB"
os.environ["AWS_SECRET_ACCESS_KEY"] = "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"
os.environ["GOOGLE_API_KEY"]="AIzaSyBs6eyE7JHovx_7Jp0RmO-SasqLaJk5rlI"
os.environ["PROJECT_ID"]="602280418311"
os.environ["DOC_AI_LOCATION"]="us"
os.environ["DOC_AI_PROCESSOR_ID"]="e977fdd46ee23308"

# %%
llm = get_llm(model_type="CLAUDE") # Gemini 1.5 works best for generating instructions

# %%
ans = llm.invoke("You’re a financial advisor. A client wants to invest $10,000. They can choose between two options: A) A stock that historically returns 12% annually but is volatile, or B) A bond that guarantees 6% annually. The client needs the money in 5 years for a down payment on a house. Which option do you recommend? Think step-by-step.")

# %%
print(ans.content)

# %%
ans = llm.invoke("You’re a financial advisor. A client wants to invest $10,000. They can choose between two options: A) A stock that historically returns 12% annually but is volatile, or B) A bond that guarantees 6% annually. The client needs the money in 5 years for a down payment on a house. Which option do you recommend?")

print(ans.content)

# %%
prompt = """
Draft personalized emails to donors asking for contributions to this year’s Care for Kids program.

Program information:
<program>Good program.
</program>

Donor information:
<donor>Good donor.
</donor>

Think before you write the email in <thinking> tags. First, think through what messaging might appeal to this donor given their donation history and which campaigns they’ve supported in the past. Then, think through what aspects of the Care for Kids program would appeal to them, given their history. Finally, write the personalized donor email in <email> tags, using your analysis.

"""

ans = llm.invoke(prompt)

print(ans.content)

# %%
p = """
Compare these two values if they are equal or not.

<value>the value is 77</value> and <value>lower than 80</value>


Think before you write the answer in <thinking> tags. 
First, think about the two values and how they compare.
Then, think about the relationship between the two values.

Finally, write the answer  in <answer> tags, using your analysis.


"""

ans = llm.invoke(p)
print(ans.content)

# %%
p = """YOU ARE A HIGHLY ACCURATE VALIDATOR, TASKED WITH COMPARING TWO KEY ITEMS TO DETERMINE IF THEIR CONTENT IS IDENTICAL. YOUR OBJECTIVE IS TO CHECK WHETHER **VALUE 1** AND **VALUE 2**  MEAN THE SAME IN VALUE AND CONTENT.

### INSTRUCTIONS ###
- COMPARE VALUES FOR EQUALITY.
- ENSURE BOTH ITEMS HAVE THE SAME MEANING AND VALUE.
- COMPARE the contents of values.
- IF the contents (or structure, in the case of complex data) means the same, RETURN **"TRUE"**.
- IF there are any differences in content or structure, RETURN **"FALSE"**.
- Output either **"TRUE"** (if values are equal) or **"FALSE"** (if they are different in any way).


### WHAT NOT TO DO ###
- DO NOT RETURN A VALUE OTHER THAN **"TRUE"** OR **"FALSE"** (e.g., avoid unnecessary descriptions or explanations).

<value1>the value is 77</value1> and <value2>lower than 80</value2>

Think before you write the answer in <thinking> tags. 
First, think about the two values and how they compare.
Then, think about the relationship between the two values.

Finally, write the answer  in <answer> tags, using your analysis."""

ans = llm.invoke(p)
print(ans.content)

# %%
ans = [('<thinking>\nThe two values describe different renewal terms:\n\nSite Lease Renewal Terms: Allows for two additional 5-year renewal periods, with a 90-day written notice required before expiration.\n\nO&M Renewal: Allows for automatic extension for consecutive 1-year periods.\n\nThe renewal periods (5 years vs. 1 year), number of renewals (two vs. consecutive), and notice requirements (written notice vs. automatic) are different between the two values. Therefore, they do not have the same meaning or value.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '92', 'document_type_1': 'Site Lease', 'key_item_1': 'Renewal Terms', 'value_1': 'Two (2) additional five (5) year periods with written notice Ninety (90) days prior to the expiration', 'document_type_2': 'O&M', 'key_item_2': 'Renewal', 'value_2': 'An automatic extension for consecutive one (1) year periods'}), ('<thinking>\nThe two values being compared are:\n1. "CityofDuQuoin, Illinois" (PPA Offtaker)\n2. "GreenLife Solar, LLC d/b/a Shine Development Partners" (Site Lease Lessee (Tenant) Entity Name)\n\nThese values are clearly different strings representing different entities. The PPA Offtaker is a city in Illinois, while the Site Lease Lessee is a company with a "doing business as" name.\n\nSince the values are not the same, they do not have the same meaning or content.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '109', 'document_type_1': 'PPA', 'key_item_1': 'Offtaker', 'value_1': 'CityofDuQuoin, Illinois', 'document_type_2': 'Site Lease', 'key_item_2': 'Lessee (Tenant) Entity Name', 'value_2': 'GreenLife Solar, LLC d/b/a Shine Development Partners'}), ('<thinking>\nThe two values being compared are:\n1. "HEG Energy, LLC" (PPA Offtaker)\n2. "Mount Kemble Morristown" (Interconnection Agreement Interconnection Customer)\n\nThese two values are clearly different strings of text, representing different entities. The PPA Offtaker refers to a company called "HEG Energy, LLC", while the Interconnection Agreement Interconnection Customer refers to a different entity called "Mount Kemble Morristown".\n\nSince the values are not identical in content or meaning, the answer is:\n</thinking>\n\n<answer>FALSE</answer>', {'name': '119', 'document_type_1': 'PPA', 'key_item_1': 'Offtaker', 'value_1': 'HEG Energy, LLC', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Interconnection Customer', 'value_2': 'Mount Kemble Morristown'}), ('<thinking>\nThe two values provided are:\n\nPPA Term: "25 years from Commercial Operation; extenable for 2 five year terms"\nEPC Term: "Owner will establish the Date of Commencement"\n\nThese two values are clearly different in their content and meaning. The PPA Term specifies a duration of 25 years with the possibility of extension, while the EPC Term refers to the owner establishing a commencement date.\n\nSince the values are not equal or equivalent in meaning, the answer should be:\n</thinking>\n\n<answer>FALSE</answer>', {'name': '58', 'document_type_1': 'PPA', 'key_item_1': 'Term', 'value_1': '25 years from Commercial Operation; extenable for 2 five year terms', 'document_type_2': 'EPC', 'key_item_2': 'Term', 'value_2': 'Owner will establish the Date of Commencement'}), ('<thinking>\nThe two values provided are:\nSite Lease Effective Date = June 27, 2019\nO&M Effective Date = July 8, 2019\n\nThese two dates are different, with the O&M Effective Date being later than the Site Lease Effective Date. Since the dates are not the same, the values do not have the same meaning or content.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '12', 'document_type_1': 'Site Lease', 'key_item_1': 'Effective Date', 'value_1': 'June 27,2019', 'document_type_2': 'O&M', 'key_item_2': 'Effective Date', 'value_2': 'July 8, 2019'}), ('<thinking>\nThe two values provided are:\nSite Lease Effective Date = June 27, 2019\nEPC Effective Date = June 5, 2019\n\nThese two dates are different, with the Site Lease Effective Date being later than the EPC Effective Date. Since the dates are not the same, the values are not equal in content or meaning.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '19', 'document_type_1': 'Site Lease', 'key_item_1': 'Effective Date', 'value_1': 'June 27,2019', 'document_type_2': 'EPC', 'key_item_2': 'Effective Date', 'value_2': 'June 5, 2019'}), ('<thinking>\nThe two values being compared are:\n1. PPA Effective Date: March 14, 2019\n2. Interconnection Agreement Effective Date: August 8, 2019\n\nThese two dates are clearly different, with the Interconnection Agreement Effective Date being later than the PPA Effective Date. Since the values are not the same, they do not have the same meaning or content.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '10', 'document_type_1': 'PPA', 'key_item_1': 'Effective Date', 'value_1': 'March 14, 2019', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Effective Date', 'value_2': 'August 8, 2019'}), ('<thinking>\nThe first value, "2000 KW", is a specific numerical value representing the nameplate capacity or system size.\n\nThe second value, "Not to exceed 2 MW", is a limit or constraint on the nameplate capacity, expressed in a different unit (MW instead of KW).\n\n2 MW is equivalent to 2000 KW, so the two values are essentially the same, with the second value expressing the limit in a different unit.\n\nTherefore, the two values have the same meaning and represent the same capacity limit, just expressed differently.\n</thinking>\n\n<answer>TRUE</answer>', {'name': '159', 'document_type_1': 'Interconnection Agreement', 'key_item_1': 'Nameplate Capacity (System Size)', 'value_1': '2000 KW', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Nameplate Capacity Limits', 'value_2': 'Not to exceed 2 MW'}), ('<thinking>\nThe two values being compared are:\n\n1. "25 years from the Commercial Operation Date" (Site Lease Initial Term)\n2. "5 years beginning on the Commencement Date and may be extended for additional 5 year period on mutual agreement." (O&M Term)\n\nThese values represent different time periods and have different starting points (Commercial Operation Date vs. Commencement Date). Additionally, the O&M Term has the possibility of extension, while the Site Lease Initial Term does not mention any extension.\n\nTherefore, the two values do not have the same meaning or content, and they are not equal.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '65', 'document_type_1': 'Site Lease', 'key_item_1': 'Initial Term', 'value_1': '25 years from the Commercial Operation Date', 'document_type_2': 'O&M', 'key_item_2': 'Term', 'value_2': '5 years beginning on the Commencement Date and may be extended for additional 5 year period on mutual agreement.'}), ('<thinking>\nThe two values are:\n1. "CityofDuQuoin, Illinois"\n2. "City of DuQuoin"\n\nWhile the second value is contained within the first value, they are not exactly identical in content and structure. The first value includes additional information ("Illinois") that is not present in the second value.\n\nEven though they refer to the same entity, the values themselves are not strictly equal. Therefore, the appropriate answer is:\n</thinking>\n\n<answer>FALSE</answer>', {'name': '118', 'document_type_1': 'PPA', 'key_item_1': 'Offtaker', 'value_1': 'CityofDuQuoin, Illinois', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Interconnection Customer', 'value_2': 'City of DuQuoin'}), ('<thinking>\nThe two values being compared are:\n1. O&M Effective Date = 8/22/2019\n2. Interconnection Agreement Effective Date = May 20, 2019\n\nThese two dates are different, representing different points in time. The O&M Effective Date is later than the Interconnection Agreement Effective Date.\n\nSince the values are not the same, the answer is:\n</thinking>\n\n<answer>FALSE</answer>', {'name': '38', 'document_type_1': 'O&M', 'key_item_1': 'Effective Date', 'value_1': '8/22/2019', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Effective Date', 'value_2': 'May 20, 2019'}), ('<thinking>\nThe two values describe renewal terms for a contract or agreement:\n\n"2 renewals at 5 years each" specifies that the contract can be renewed twice, with each renewal period lasting 5 years.\n\n"May be extended for additional 5 year periods on mutual agreement" indicates that the contract can be extended for additional 5-year periods, as long as both parties agree to it.\n\nWhile the wording is slightly different, the core meaning is the same: both values allow for the contract to be renewed or extended for additional 5-year periods, with the second value adding the condition of mutual agreement between the parties.\n\nTherefore, the two values can be considered equivalent in meaning and value.\n</thinking>\n\n<answer>TRUE</answer>', {'name': '99', 'document_type_1': 'PPA', 'key_item_1': 'Renewal Terms', 'value_1': '2 renewals at 5 years each', 'document_type_2': 'O&M', 'key_item_2': 'Renewal', 'value_2': 'May be extended for additional 5 year periods on mutual agreement.'}), ('<thinking>\nThe two values seem to be referring to the same concept - the date when the project starts commercial operations and begins selling energy. However, the wording is slightly different:\n\n"Commercial Operation Date" is a more concise term, while "When Company delivers notice to Provider that the Project is first placed into commercial operation and selling usable energy to JCP&L" provides more details on the specific conditions that define this date.\n\nDespite the difference in wording, the underlying meaning appears to be the same - the date when the project becomes operational and starts selling energy commercially.\n</thinking>\n\n<answer>TRUE</answer>', {'name': '107', 'document_type_1': 'Site Lease', 'key_item_1': 'Rent Commencement', 'value_1': 'Commercial Operation Date', 'document_type_2': 'O&M', 'key_item_2': 'Commencement Date', 'value_2': 'When Company delivers notice to Provider that the Project is first placed into commercial operation and selling usable energy to JCP&L.'}), ('<thinking>\nThe Interconnection Agreement Nameplate Capacity (System Size) is given as "2 MW".\nThe Interconnection Agreement Nameplate Capacity Limits is stated as "Not to exceed 2 MW".\n\nBoth values indicate a maximum capacity of 2 MW, just expressed differently. The first value directly states the capacity as 2 MW, while the second value expresses it as a limit not to exceed 2 MW.\n\nSince the maximum capacity is the same in both cases, the values can be considered equal in meaning and content.\n</thinking>\n\n<answer>TRUE</answer>', {'name': '145', 'document_type_1': 'Interconnection Agreement', 'key_item_1': 'Nameplate Capacity (System Size)', 'value_1': '2 MW', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Nameplate Capacity Limits', 'value_2': 'Not to exceed 2 MW'}), ('<thinking>\nThe two values "CityofDuQuoin, Illinois" and "DuQuoin Solar, LLC" are different strings. They do not have the same meaning or content.\n\nThe first value "CityofDuQuoin, Illinois" appears to refer to the city of DuQuoin in the state of Illinois. The second value "DuQuoin Solar, LLC" seems to be the name of a company, likely related to solar energy and based in DuQuoin.\n\nSince these two values are distinct and refer to different entities, they cannot be considered equal in value or content.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '112', 'document_type_1': 'PPA', 'key_item_1': 'Offtaker', 'value_1': 'CityofDuQuoin, Illinois', 'document_type_2': 'O&M', 'key_item_2': 'Customer', 'value_2': 'DuQuoin Solar, LLC'}), ('<thinking>\nThe two values being compared are:\n1. Site Lease Effective Date = March 14, 2019\n2. Interconnection Agreement Effective Date = August 8, 2019\n\nThese two dates are different, representing different points in time. The Site Lease Effective Date is earlier than the Interconnection Agreement Effective Date.\n\nSince the values are not the same, the answer is:\n</thinking>\n\n<answer>FALSE</answer>', {'name': '29', 'document_type_1': 'Site Lease', 'key_item_1': 'Effective Date', 'value_1': 'March 14, 2019', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Effective Date', 'value_2': 'August 8, 2019'}), ('<thinking>\nThe two values provided are:\n1. Site Lease Effective Date = June 27, 2019\n2. Interconnection Agreement Effective Date = February 11, 2019\n\nThese two dates are different, representing different points in time. The Site Lease Effective Date is later than the Interconnection Agreement Effective Date.\n\nSince the values are not the same, the answer is:\n</thinking>\n\n<answer>FALSE</answer>', {'name': '25', 'document_type_1': 'Site Lease', 'key_item_1': 'Effective Date', 'value_1': 'June 27,2019', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Effective Date', 'value_2': 'February 11, 2019'}), ('<thinking>\nThe two values being compared are:\n\n1. "25 years from Commercial Operation; extenable for 2 five year terms"\n2. "25 years from the Commercial Operation Date"\n\nBoth values indicate an initial term of 25 years from the Commercial Operation Date. The first value also mentions the possibility of extending the term for two additional 5-year periods, while the second value does not mention any extension.\n\nHowever, the key comparison is the initial term, which is the same in both cases: 25 years from the Commercial Operation Date.\n\nTherefore, the two values can be considered equal for the purpose of comparing the initial term.\n</thinking>\n\n<answer>TRUE</answer>', {'name': '54', 'document_type_1': 'PPA', 'key_item_1': 'Term', 'value_1': '25 years from Commercial Operation; extenable for 2 five year terms', 'document_type_2': 'Site Lease', 'key_item_2': 'Initial Term', 'value_2': '25 years from the Commercial Operation Date'}), ('<thinking>\nThe PPA Nameplate Capacity is given as "Less than 5 MW", which is a range rather than a specific value. The Interconnection Agreement Nameplate Capacity (System Size) is given as "3.00 MW", which is a specific value within the range of "Less than 5 MW".\n\nSince the Interconnection Agreement Nameplate Capacity (System Size) of 3.00 MW falls within the range specified by the PPA Nameplate Capacity of "Less than 5 MW", the two values are consistent and mean the same thing in terms of the system size or capacity.\n</thinking>\n\n<answer>TRUE</answer>', {'name': '121', 'document_type_1': 'PPA', 'key_item_1': 'Nameplate Capacity', 'value_1': 'Less than 5 MW', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Nameplate Capacity (System Size)', 'value_2': '3.00 MW'}), ('<thinking>\nThe two values being compared are:\n\n1. "15 years from COD."\n2. "3.2 - Begins Effective Date and remains in effect unless terminated by Article 3.3."\n\nThese values are clearly different in their content and meaning. The first value specifies a fixed term of 15 years from the Commercial Operation Date (COD), while the second value refers to an Interconnection Agreement that begins on an Effective Date and remains in effect indefinitely unless terminated according to Article 3.3.\n\nSince the two values have different meanings and implications, they cannot be considered equal or identical in value and content.\n</thinking>\n\n<answer>FALSE</answer>', {'name': '82', 'document_type_1': 'O&M', 'key_item_1': 'Term', 'value_1': '15 years from COD.', 'document_type_2': 'Interconnection Agreement', 'key_item_2': 'Term', 'value_2': '3.2 - Begins Effective Date and remains in effect unless terminated by Article 3.3.'})]

# %%
for a in ans:
    print(a[0])
    print()

# %%
import pandas as pd

a = pd.concat((
    
    pd.read_csv("/Users/odeine/PycharmProjects/ilios-DocAI/src/pipelines/co_terminus_check/report-1729782119.9000561.csv"),
    pd.read_csv("/Users/odeine/PycharmProjects/ilios-DocAI/src/pipelines/co_terminus_check/report.csv"),))
a[a["ans"] != a["pred"]].head(30).to_csv("co_terminus_check.csv", index=False)

# %% [markdown]
# ## Specify the pipeline configuration

# %%
from src.pipelines.term_extraction.pipeline_config import PipelineConfig, LoanAgreementPipelineConfig
import pathlib

pipeline_config = LoanAgreementPipelineConfig(use_gcs_storage=True)

main_path = pathlib.Path().absolute().parent.parent
pipeline_folder = Path(main_path / f"src/pipelines/terms/{pipeline_config.pipeline_name}")

instructions_path = pipeline_folder / "terms-instructions.csv"
terms_and_instructions = pd.read_csv(pipeline_folder / "terms-instructions.csv")
terms_and_definitions = pd.read_csv(pipeline_folder / "terms-definitions.csv")

# %% [markdown]
# #### Load the few-shot data

# %%
def load_few_shots(pipeline_config: PipelineConfig) -> pd.DataFrame:
    few_shots_legal_terms = []
    print(pipeline_config.few_shot_file_names)
    for file_name in pipeline_config.few_shot_file_names:
        print(f"File: {file_name}")

        correct_project_preview = get_project_preview(pipeline_config.get_project_previews_path(), file_name)
        print(correct_project_preview.columns)
        few_shots_legal_terms.append(
            correct_project_preview[["Key Items", "Value", "Legal Terms"]].assign(file_name=file_name))

    return pd.concat(few_shots_legal_terms)


legal_terms = load_few_shots(pipeline_config)

# %%
legal_terms = legal_terms.sort_values(["Key Items"])
legal_terms = legal_terms[legal_terms["Legal Terms"] != "Not provided."]  # Remove rows with no legal terms
legal_terms.head()

# %%
few_shots = legal_terms.copy()
few_shots["Example"] = legal_terms["Legal Terms"]  # Use Legal Terms as Example
few_shots = few_shots.groupby("Key Items")["Example"].unique()  # Create set of examples for each Key Item
few_shots.head()

# %%
terms_and_instructions["Key Items"].to_list()

# %%
few_shots = terms_and_instructions[["Key Items"]].merge(few_shots, on="Key Items", how="left")
few_shots = few_shots.merge(terms_and_definitions, on="Key Items", how="left")

# %%
few_shots["Example"].apply(type)

# %%
def few_shots_to_prompt(few_shots) -> str:
    ans = """Build a prompt for Claude LLM model to extract this citations of Legal Terms: {key_item} 
    
<example_of_instructions>
    
## Finding Parties in a document

**Prompt:**

Given a site lease document, identify and extract sections of text that define the involved parties, specifically the Landlord and Tenant (or Lessor and Lessee). Use the following guidelines:

**Keywords and Patterns:**

* Look for phrases like:
    * "by and between"
    * "this Lease" or "this Agreement"
    * "Landlord" and "Tenant" (or "Lessor" and "Lessee")
    * "Party" and "Parties"
* Identify company names, often followed by identifiers such as:
    * LLC (Limited Liability Company)
    * Inc. (Incorporated)
    * Corporation
    * Trust
    * Individual names, possibly followed by titles like Trustee
* Look for addresses associated with the company or individual names.
* Pay attention to quotation marks surrounding names or titles, and parentheses often containing additional information like state of incorporation.
* Look for patterns like:
    * **[Company Name], a [State] [Company Type], with an address at [Address] ("[Landlord/Tenant/Lessor/Lessee]")**
    * **between [Company/Individual Name] (the "[Landlord/Lessor]") and [Company/Individual Name] (the "[Tenant/Lessee]")**

**Example:**

In the phrase:
>"**By and between HEELSTONE LAND HOLDINGS, LLC, a Delaware limited liability company (the “Landlord”) and 233 RANDOLPH 74 SOLAR I, LLC, a North Carolina limited liability company (the “Tenant”).**"

* "By and between" indicates the start of the relevant section.
* "HEELSTONE LAND HOLDINGS, LLC" and "233 RANDOLPH 74 SOLAR I, LLC" are the company names.
* "Delaware limited liability company" and "North Carolina limited liability company" identify the company types.
* "(the “Landlord”)" and "(the “Tenant”)" explicitly label the roles of each party.

Term to look for: Lessor (Landlord) Entity Name
Definition of term: The individual or entity who holds title to the property and is leasing to REA controlled entity

<example_of_instructions/>

    
    
    Term to build instructions for - {key_item}
    Definition of the term - {definition}
    Examples of extracted Legal Terms:
    
"""
    if isinstance(few_shots["Example"], np.ndarray):

        ans += """\nExamples of extracted Legal Terms:
"""

        for legal_terms in few_shots["Example"][:3]:
            ans += """
<example_of_extracted_legal_terms>
{legal_terms}...
</example_of_extracted_legal_terms>

Prompt similar to example for extracting of information for {key_item}:
""".format(legal_terms=legal_terms[:400], key_item=few_shots["Key Items"])

    return ans.format(key_item=few_shots["Key Items"], definition=few_shots["Definitions"])

# %%
few_shots = pd.DataFrame(
    [
        {
            "Key Items": "Promissory Note",
            "Example": [
                """FOR VALUE RECEIVED, the undersigned, Canton GLC Solar, LLC, a Maine limited
liability company (hereinafter referred to as “Borrower”), promises to pay to the order of M1 Bank,
a Missouri chartered bank, whose address is 7 N. Bemiston Ave., Clayton, Missouri 63105
(hereinafter referred to as the “Lender”), the principal sum of EIGHT MILLION THREE
HUNDRED FOURTEEN THOUSAND SEVEN HUNDRED FIFTY AND NO/100 DOLLARS
($8,314,750.00), with interest on such amount of principal as may be outstanding from time to
time as provided herein.""",
                """FOR VALUE RECEIVED, the undersigned, 233 Randolph 74 Solar I, LLC, a North Carolina limited liability company (hereinafter referred to as “Borrower”), promises to pay to the order of Crestmark, a division of MetaBank, National Association, whose address is 5480 Corporate Drive, Suite 350, Troy, Michigan 48098 (hereinafter referred to as the “Lender”), the principal sum of THREE MILLION TWO HUNDRED SEVENTY-SIX THOUSAND FIVE HUNDRED THIRTY-EIGHT AND 00/100 DOLLARS ($3,276,538.00), with interest on such amount of principal as may be outstanding from time to time as provided herein."""
            ],
            "Definitions": "A promissory note is a financial instrument that contains a written promise by one party (the note's issuer or maker) to pay another party (the note's payee) a definite sum of money, either on demand or at a specified future date."
        },
        
        
        
        
        
        
        
        
        
    ]
    
    
    
    
    
)

# %%
def generate_prompts(few_shots: pd.DataFrame) -> List[str]:
    prompts = []

    for _, few_shots_row in few_shots[["Key Items", "Example", "Definitions"]].iterrows():
        prompts.append(few_shots_to_prompt(few_shots_row))
    return prompts


prompts = generate_prompts(few_shots)

# %%
for prompt in prompts:
    print(prompt)

# %%
llm = get_llm(model_type="CLAUDE") # Gemini 1.5 works best for generating instructions


def generate_instructions_from_prompts(prompts: pd.Series, llm: LLMChain) -> List[str]:
    instructions = []
    for prompt in tqdm(prompts):
        instructions.append(llm.invoke(prompt))
    return instructions


instructions = generate_instructions_from_prompts(prompts, llm)

# %%
for instruction in instructions:
    print(instruction.content)

# %%
def save_instructions(instructions: List[str], instructions_path: Path) -> None:
    def postprocess(text: str) -> str:
        if text.startswith("```"):
            text = text[3:]
        if text.endswith("```"):
            text = text[:-3]
        return text.strip()

    instructions = [postprocess(instruction.content) for instruction in instructions]
    terms_and_instructions = pd.read_csv(instructions_path)
    terms_and_instructions["Instructions"] = instructions

    path_to_save = instructions_path.parent / f"terms-instructions_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.csv"
    terms_and_instructions.to_csv(path_to_save, index=False)

save_instructions(instructions, instructions_path)
